# %% [markdown]
# В @A:\tbot-controls-pc\.prompts\initial_promps.ipynb два драфта начального промпта для агента Cursor. Нужно убрать лишнее, запросить недостающее, и составить профессиональный стартовый промт, оформленный и с учётом лучших практик: @A:\tbot-controls-pc\docs\cursor-25H2-best-practicies.md
#
# 1. Поищи в интернете самые ли актуальные и современные библиотеки предлагаются, замени, если надо.
# 2. `settings.env` с утсановленной переменной `TELEGRAM_BOT_TOKEN` уже лежит в корне открытого в Cursor проекта (`A:\tbot-controls-pc\`)
# 3. Фичи:
#     1. Кнопка ⏯️
#     2. Кнопка 💤
#     3. Кнопки 🔉и 🔊 для уменьшения и увеличения громкости
# 4. В рамках изучения лучших практик Куросор я планирую примерно такой воркфлоу:
#     - в "мастер-чате" составить план с тремя фазами и сохранить его в `A:\tbot-controls-pc\plan.md`
#     - сдублировать мастер-чат, назвать новый чат "фича 1"
#     - разработать и протестировать фичу 1, задокументировать статус проекта, сделать комит и и пуш на `https://github.com/DiscipulusVitae/tbot-controls-pc`
#     - повторить позапрошлый и прошлый шаги для фич 2 и 3, только в конце "финализировать" проект, оставив его открытым для проектирования и реализации новых фич

# %% [markdown]
# Я установил Go. Продолжай.
# ```
# PS a:\tbot-controls-pc> winget install GoLang.Go
# Найдено Go Programming Language [GoLang.Go] Версия 1.25.0
# Лицензия на это приложение предоставлена вам владельцем.
# Корпорация Майкрософт не несет ответственность за сторонние пакеты и не предоставляет для них никакие лицензии.
# Скачивание https://go.dev/dl/go1.25.0.windows-amd64.msi
#   ██████████████████████████████  53.5 MB / 53.5 MB
# Хэш установщика успешно проверен
# Запуск установки пакета...
# Успешно установлено
# ```

# %% [markdown]
# Я выполнил:
# ```
# PS A:\tbot-controls-pc> go mod init tbot-controls-pc
# go: creating new go.mod: module tbot-controls-pc
# go: to add module requirements and sums:
#         go mod tidy
# ```
# Так же затем перезапустил Cursor (ты - LLM агента Курсор). Тепрь команды go должны отрабатывать.

# %% [markdown]
# Хорошо. Я добавил в `settings.env` строчку вида `TELEGRAM_USER_ID="1234567890"` с моим реальным ID.

# %% [markdown]
# PS A:\tbot-controls-pc> go run main.go
# main.go:9:2: no required module provides package github.com/go-telegram-bot-api/telegram-bot-api/v5; to add it:
#         go get github.com/go-telegram-bot-api/telegram-bot-api/v5

# %% [markdown]
# Запустил main.go в терминале. Стартовал бота в тг. Не вижу кнопок.

# %% [markdown]
# Запустил main.go в терминале. Стартовал бота в тг командой /start. Не вижу кнопок. Прервал в терминале. Не вижу log файлов.

# %% [markdown]
# Отлично. При запуске экзешника сразу появились кнопки. Бот реагирует на их нажатие.

# %% [markdown]
# Отлично. При запуске экзешника сразу появились кнопки. Бот реагирует на их нажатие.
# Я перенёс plan.md в `A:\tbot-controls-pc\`.
# Сохрани всю историю действий после создания плана в `A:\tbot-controls-pc\project-state.md` и остановись.

# %% [markdown]
# ---

# %% [markdown]
# Этап 1 реализован уже реализован. Журнал изменений тут: @project-state.md
# Экзешник `A:\tbot-controls-pc\tbot-controls-pc.exe` отрабатывает, создаёт лог.
# Я перенёс plan.md в `A:\tbot-controls-pc\`. В этой сессии ты реализуешь этап 2 и ничего больше. Мы его тестируем. Ты дополняешь `project-state.md`. Делаем комит и пуш.
# ---
# Дальше будет аналогичным образом реализация этапа 3, но уже в другом чате. Приступай.

# %% [markdown]
# Я перенёс plan.md в `A:\tbot-controls-pc\`. Обогати его описанием воркфлоу для каждого этапа. Вот пример для 2-го этапа:
# ```
# В этой сессии ты реализуешь этап 2 и ничего больше. После реализации кода, ты даёшь инструкции для тестирования и останавливаешься. Мы его тестируем и дорабатываем, если потребуется. Когда я подтвержу, что фича готова, ты дополняешь `project-state.md`. Затем делаешь комит и пуш.
# ```
# Так для каждого этапа, только в конце последнего (в текущем плане это Этап 4) мы "подытоживаем" проект, оставив его открытым для проектирования и реализации новых фич.
# ---
# Я добавил в енв-файл строку `GITHUB_REPO_URL="https://github.com/DiscipulusVitae/tbot-controls-pc"`.

# %% [markdown]
# Я добавил в енв-файл строку `GITHUB_REPO_URL="https://github.com/DiscipulusVitae/tbot-controls-pc"`.
# Я перенёс plan.md в `A:\tbot-controls-pc\` и немного дополнил его. Прочти.
# Сейчас работаем ТОЛЬКО над планом.

# %% [markdown]
# Если я в этом месте сдублирую наш чат в новый и напишу
# ```
# В этой сессии работаем только над этапом 3 и ничем больше. Прочти plan.md (общий план проекта с описанием этапов) и project-state.md (история реализации прошлых этапов) и приступай.
# ```
# Агент всё правильно поймёт и приступит к действиям форкфлоу?

# %% [markdown]
# Всё отработало, компьютер выключился.

# %% [markdown]
# Я выполнил:
# ```
# rm .git
# git init
# git add .
# git commit -m "Initial commit. Этап 3 завершен."
# git push https://github.com/DiscipulusVitae/tbot-controls-pc
# ```
# Акутализируй @project-state.md

# %% [markdown]
# Прекрасно, обе кнопки меняют громкость на компе. Но лишь на 2 из 100. Где мне в Windows посмотреть настройки? Хочу, чтоб менялось на 10.

# %% [markdown]
# Объясни почему ты заменяешь SendMediaKey(0xAE) на SendMediaKey(VK_VOLUME_DOWN)?

# %% [markdown]
# ```
# PS A:\tbot-controls-pc> go build -ldflags "-H=windowsgui" -o tbot-controls-pc.exe .
# PS A:\tbot-controls-pc> .\tbot-controls-pc.exe
# PS A:\tbot-controls-pc>
# ```
# После такой компиялции и запуска я не могу прекратить выполнение программы по Ctrl+C. Так же я не вижу экзэшник в диспетчере задая. Что будет если после следующей доработки просто запустить вновь откомпилированный экзешник?

# %% [markdown]
# Прочитай файлы плана и статуса. Я накидал пятый этап, дополни. В плане вынеси описание форкфлоу в шапку, убери многократное повторение в каждом этапе.

# %% [markdown]
# Добавил строку вида PC_MAC_ADDRESS="00-1B-44-11-3A-B7" с реальным адресом компа. Актуализируй план.

# %% [markdown]
# Понял, спасибо.
# * Кнопки отрабатывают как ожидалось.
# * Ридми пока не нужен, удали. Я сейчас добавил в план 5 этап.
# * Актуализируй файл статуса проекта.

# %% [markdown]
# Не спеши, сначала тест. Я запустил и не обнаружил в боте новой пятой кнопки для включения. Пусть кнопки будут расположены в два ряда:
# 🔌💤
# ⏯️🔉🔊
# Добавь эту корректировку в план 5го этапа и приступай.

# %% [markdown]
# Прочитай план. Я немного опростоволосился с этапом 5. Если комп выключен, некому посылать волшебный пакет включения WOL. Давай подумаем над вариантами как перенести этот функционал на телефон. Think harder.

# %% [markdown]
# У меня роутер TP-Link Archer C80. Поищи в инете позволяет ли он запускать простой веб-сервер.

# %% [markdown]
# Фичу 5-го этапа ("🔌") придётся откатить и удалить все упоминания из плана. WOL придётся делать вне бота (или не делать вообще). В целом 5 этап надо убрать из плана. Кнопки в боте пусть будут расположены так:
# 💤
# ⏯️🔉🔊
#
# Сделай это и актуализируй файл статуса.

# %% [markdown]
# Некорректно обновил файл статуса. Прочти его целиком, потом обновляй.
#
# Протестировал, бот работает как ожидается.

# %% [markdown]
# Прочитай файлы плана и статуса проекта. Я немного опростоволосился с этапом 5. Если комп выключен, некому посылать волшебный пакет включения WOL.
#
# Давай спланируем как финализировать проект.
# - Надо сделать релиз комит и пуш с тэгом "v1.0.0" (последний шаг)
# - Надо добавить инструкцию по настройке автозагрузки утилиты в Планировщике Windows
# - Что ещё надо?

# %% [markdown]
# Да. Только всегда читай целиком файлы, которые хочешь редактировать.

# %% [markdown]
# Очень неплохо. Но убери процентов 10 наименне важной информации из новых файлов. И сам будь менее многословным, фокусируйся на ключевых моментах процесса, а не на overexplaining.
#
# У тебя плохо получилось с `.gitignore`. Убери все упоминания этого действия и не выполняй его. Гит работает как надо.
#
# Давай причешем файловую структуру. Пусть имена md файлов будут в одном регистре, создай папку src, перенеси в неё файлы и т.д.

# %% [markdown]
# Доработал ридми. Перенеси 2 md-файла проекта в папку докс. Актуализируй ищменения в доках.
#
# И напиши инструкции как сделать релиз.

# %% [markdown]
# Я поспешил сделать комит и пуш. Как их откатить? Экзешник ведь теперь надо исключить из гитигнор. Сделал это. И ещё, ты написал в ридми Скачаивание из последнего релиза. Но по этой ссылке на гитхабе пусто. Что нужно сделать, чтоб появился релиз?
